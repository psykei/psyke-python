# %% [markdown]
# # PSyKE's demo for regression comparison
#
# Some imports.

# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from os.path import exists
from psyke import Extractor
from psyke.utils.logic import pretty_theory
from psyke.regression import FeatureRanker
from psyke.optimizer.pedro import PEDRO
from psyke.optimizer.crash import CRASH
from psyke.utils import Target
from psyke.optimizer import Objective

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# Loading black-box models

# %%
PATH = "../test/resources/"
datasets = ["contingency", "contingency", "anticipate", "anticipate", "contingency", "anticipate"]
models = [
    "CONTINGENCY_no_input-memory_DecisionTree_MaxDepth10",
    "CONTINGENCY_no_input-time_DecisionTree_MaxDepth10",
    "ANTICIPATE_no_input-memory_DecisionTree_MaxDepth10",
    "ANTICIPATE_no_input-time_DecisionTree_MaxDepth10",
    "CONTINGENCY_input-cost_DecisionTree_MaxDepth15",
    "ANTICIPATE_input-cost_DecisionTree_MaxDepth15"
]
models = [
    pickle.load(open(f"{PATH}predictors/{dataset}/{path}", 'rb')) for path, dataset in zip(models, datasets)
]

# %% [markdown]
# Function to pre-process data

# %%
def process(dataset):
    df = pd.read_csv(f"{PATH}datasets/{dataset}_trainDataset.csv")

    # Removes header entries
    df = df[df['sol(keuro)'] != 'sol(keuro)']

    # Fixed stuff which is always there
    df['PV(kW)'] = df['PV(kW)'].map(lambda entry: entry[1:-1].split())
    df['PV(kW)'] = df['PV(kW)'].map(lambda entry: list(np.float_(entry)))
    df['Load(kW)'] = df['Load(kW)'].map(lambda entry: entry[1:-1].split())
    df['Load(kW)'] = df['Load(kW)'].map(lambda entry: list(np.float_(entry)))

    X = pd.DataFrame()

    X['PV_mean'] = df['PV(kW)'].map(lambda entry: np.array(entry).mean())
    X['PV_std'] = df['PV(kW)'].map(lambda entry: np.array(entry).std())
    X['Load_mean'] = df['Load(kW)'].map(lambda entry: np.array(entry).mean())
    X['Load_std'] = df['Load(kW)'].map(lambda entry: np.array(entry).std())
    X['nScenarios'] = df['nScenarios']
    X['cost'] = df['sol(keuro)']
    X['time'] = df['time(sec)']
    X['memo'] = df['memAvg(MB)']

    X.to_csv(f"{PATH}datasets/{dataset}.csv", index = False)

    return X

# %% [markdown]
# Experiment setting

# %%
toRemove = [
    ['PV_mean', 'PV_std', 'Load_mean', 'Load_std', 'time', 'cost'],
    ['PV_mean', 'PV_std', 'Load_mean', 'Load_std', 'memo', 'cost'],
    ['PV_mean', 'PV_std', 'Load_mean', 'Load_std', 'time', 'cost'],
    ['PV_mean', 'PV_std', 'Load_mean', 'Load_std', 'memo', 'cost'],
    ["time", "memo"],
    ["time", "memo"]
]

features = [
    ["nTraces"],
    ["nTraces"],
    ["nScenarios"],
    ["nScenarios"],
    ['PV_mean', 'PV_std', 'Load_mean', 'Load_std', 'nTraces'],
    ['PV_mean', 'PV_std', 'Load_mean', 'Load_std', 'nScenarios']
]

targets = ["memo", "time", "memo", "time", "cost", "cost"]

# %% [markdown]
# Knowledge extraction with CReEPy, GridREx, GridEx and CART

# %% [markdown]
# Automated selection of the best hyper-parameters for GridREx and GridEx with PEDRO algorithm.
# For CReEPy we use CRASH, a work-in-progress procedure to tune its parameters.

# %%
best_params = {
    'GridREx': [],
    'GridEx': [],
    'CReEPy': []
}

for rem, feat, target, dataset, model in zip(toRemove, features, targets, datasets, models):
    print(f"Dataset: {dataset}, Output variable: {target}, Input features: {len(feat)}")
    name = f"{PATH}datasets/{dataset}.csv"

    if not exists(name):
        process(dataset)

    dataset = pd.read_csv(name).drop(rem, axis = 1)
    ranked = FeatureRanker(dataset.columns[:-1]).fit(model, dataset.iloc[:, :-1]).rankings()

    train, test = train_test_split(dataset, test_size=0.2, random_state=10)
    model.fit(train.iloc[:, :-1], train.iloc[:, -1])

    print("\n============GridREx parameter auto-tuning with PEDRO============\n")
    pedro = PEDRO(model, train, max_mae_increase=1.2, min_rule_decrease=0.9, readability_tradeoff=0.1,
                  max_depth=2, patience=1, algorithm=PEDRO.Algorithm.GRIDREX, objective=Objective.MODEL)
    pedro.search()
    best_params['GridREx'].append(pedro.get_best()[0])

    print("\n============GridEx parameter auto-tuning with PEDRO============\n")
    pedro = PEDRO(model, train, max_mae_increase=1.2, min_rule_decrease=0.9, readability_tradeoff=0.1,
                  max_depth=2, patience=1, algorithm=PEDRO.Algorithm.GRIDEX, objective=Objective.MODEL)
    pedro.search()
    best_params['GridEx'].append(pedro.get_best()[0])

    print("\n============CReEPy parameter auto-tuning with CRASH============\n")
    crash = CRASH(model, train, readability_tradeoff=0.1, max_depth=5, patience=1,
                  algorithm=CRASH.Algorithm.CReEPy, objective=Objective.MODEL)
    crash.search()
    best_params['CReEPy'].append(crash.get_best()[0])

    print("\n*************************************************************************************\n")
# Out:
# Dataset: contingency, Output variable: memo, Input features: 1
#
# ============GridREx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 1.91. MAE = 2.33, 2 rules
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 3.82. MAE = 2.31, 1 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 1.91. MAE = 2.31, 3 rules
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 3.82. MAE = 2.31, 1 rules
#
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 1.91. MAE = 2.33, 2 rules
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 3.82. MAE = 2.31, 1 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 1.91. MAE = 2.29, 4 rules
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 3.82. MAE = 2.31, 1 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 1.91. MAE = 2.32, 2 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 3.82. MAE = 2.31, 1 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 1.91. MAE = 2.03, 6 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 3.82. MAE = 2.31, 1 rules
#
# **********************
# Best Algorithm.GRIDREX
# **********************
# MAE = 2.29, 4 rules
# Threshold = 1.91
# Iterations = 2
# Strategy = Fixed (3)
#
# **********************
# Best   MAE
# **********************
# MAE = 2.03, 6 rules
# Threshold = 1.91
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best N rules
# **********************
# MAE = 2.31, 1 rules
# Threshold = 3.82
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
#
# ============GridEx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 1.91. MAE = 2.59, 2 rules
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 3.82. MAE = 2.50, 1 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 1.91. MAE = 2.32, 4 rules
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 3.82. MAE = 2.50, 1 rules
#
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 1.91. MAE = 2.33, 3 rules
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 3.82. MAE = 2.50, 1 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 1.91. MAE = 2.18, 9 rules
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 3.82. MAE = 2.50, 1 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 1.91. MAE = 2.34, 5 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 3.82. MAE = 2.50, 1 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 1.91. MAE = 2.07, 18 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 3.82. MAE = 2.50, 1 rules
#
# **********************
# Best Algorithm.GRIDEX
# **********************
# MAE = 2.32, 4 rules
# Threshold = 1.91
# Iterations = 2
# Strategy = Fixed (2)
#
# **********************
# Best   MAE
# **********************
# MAE = 2.07, 18 rules
# Threshold = 1.91
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best N rules
# **********************
# MAE = 2.50, 1 rules
# Threshold = 3.82
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
#
# ============CReEPy parameter auto-tuning with CRASH============
#
# Algorithm.CReEPy. Depth: 1. Threshold = 3.43. MAE = 2.82, 2 rules
# Algorithm.CReEPy. Depth: 1. Threshold = 5.34. MAE = 2.82, 2 rules
#
# Algorithm.CReEPy. Depth: 2. Threshold = 3.43. MAE = 2.48, 2 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 5.34. MAE = 2.48, 2 rules
#
# Algorithm.CReEPy. Depth: 3. Threshold = 3.43. MAE = 2.62, 2 rules
# Algorithm.CReEPy. Depth: 3. Threshold = 5.34. MAE = 2.48, 2 rules
# Algorithm.CReEPy. Depth: 3. Threshold = 7.25. MAE = 2.82, 2 rules
#
# **********************
# Best Algorithm.CReEPy
# **********************
# MAE = 2.48, 2 rules
# Threshold = 5.34
# Depth = 3
#
# **********************
# Best   MAE
# **********************
# MAE = 2.48, 2 rules
# Threshold = 5.34
# Depth = 3
#
# **********************
# Best N rules
# **********************
# MAE = 2.82, 2 rules
# Threshold = 7.25
# Depth = 3
#
#
# *************************************************************************************
#
# Dataset: contingency, Output variable: time, Input features: 1
#
# ============GridREx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 0.41. MAE = 0.76, 2 rules
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 0.82. MAE = 0.82, 1 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 0.41. MAE = 0.75, 4 rules
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 0.82. MAE = 0.82, 1 rules
#
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 0.41. MAE = 0.71, 3 rules
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 0.82. MAE = 0.82, 1 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 0.41. MAE = 0.68, 7 rules
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 0.82. MAE = 0.82, 1 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.41. MAE = 0.69, 5 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.82. MAE = 0.82, 1 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.41. MAE = 0.47, 19 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.82. MAE = 0.82, 1 rules
#
# **********************
# Best Algorithm.GRIDREX
# **********************
# MAE = 0.69, 5 rules
# Threshold = 0.41
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best   MAE
# **********************
# MAE = 0.47, 19 rules
# Threshold = 0.41
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best N rules
# **********************
# MAE = 0.82, 1 rules
# Threshold = 0.82
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
#
# ============GridEx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 0.41. MAE = 7.68, 2 rules
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 0.82. MAE = 7.68, 2 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 0.41. MAE = 3.83, 4 rules
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 0.82. MAE = 3.83, 4 rules
#
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 0.41. MAE = 4.74, 3 rules
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 0.82. MAE = 4.74, 3 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 0.41. MAE = 1.77, 9 rules
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 0.82. MAE = 1.77, 9 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.41. MAE = 3.08, 5 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.82. MAE = 3.08, 5 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.41. MAE = 0.82, 25 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.82. MAE = 0.82, 25 rules
#
# **********************
# Best Algorithm.GRIDEX
# **********************
# MAE = 3.08, 5 rules
# Threshold = 0.41
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best   MAE
# **********************
# MAE = 0.82, 25 rules
# Threshold = 0.41
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best N rules
# **********************
# MAE = 7.68, 2 rules
# Threshold = 0.41
# Iterations = 1
# Strategy = Fixed (2)
#
#
# ============CReEPy parameter auto-tuning with CRASH============
#
# Algorithm.CReEPy. Depth: 1. Threshold = 0.74. MAE = 20.66, 2 rules
# Algorithm.CReEPy. Depth: 1. Threshold = 1.15. MAE = 18.08, 2 rules
# Algorithm.CReEPy. Depth: 1. Threshold = 1.56. MAE = 18.08, 2 rules
#
# Algorithm.CReEPy. Depth: 2. Threshold = 0.74. MAE = 17.38, 3 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 1.15. MAE = 16.38, 2 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 1.56. MAE = 13.01, 2 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 1.98. MAE = 16.13, 2 rules
#
# **********************
# Best Algorithm.CReEPy
# **********************
# MAE = 13.01, 2 rules
# Threshold = 1.56
# Depth = 2
#
# **********************
# Best   MAE
# **********************
# MAE = 13.01, 2 rules
# Threshold = 1.56
# Depth = 2
#
# **********************
# Best N rules
# **********************
# MAE = 16.13, 2 rules
# Threshold = 1.98
# Depth = 2
#
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: memo, Input features: 1
#
# ============GridREx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 2.08. MAE = 4.16, 2 rules
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 4.16. MAE = 4.16, 2 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 2.08. MAE = 3.40, 4 rules
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 4.16. MAE = 3.53, 3 rules
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 6.25. MAE = 4.47, 1 rules
#
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 2.08. MAE = 3.81, 3 rules
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 4.16. MAE = 3.91, 2 rules
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 6.25. MAE = 4.47, 1 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 2.08. MAE = 3.30, 9 rules
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 4.16. MAE = 3.51, 3 rules
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 6.25. MAE = 4.47, 1 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 2.08. MAE = 3.18, 5 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 4.16. MAE = 3.40, 2 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 6.25. MAE = 4.47, 1 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 2.08. MAE = 2.18, 25 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 4.16. MAE = 3.40, 2 rules
#
# **********************
# Best Algorithm.GRIDREX
# **********************
# MAE = 3.18, 5 rules
# Threshold = 2.08
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best   MAE
# **********************
# MAE = 2.18, 25 rules
# Threshold = 2.08
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best N rules
# **********************
# MAE = 4.47, 1 rules
# Threshold = 6.25
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
#
# ============GridEx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 2.08. MAE = 33.22, 2 rules
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 4.16. MAE = 33.22, 2 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 2.08. MAE = 17.78, 4 rules
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 4.16. MAE = 17.78, 4 rules
#
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 2.08. MAE = 22.74, 3 rules
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 4.16. MAE = 22.74, 3 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 2.08. MAE = 8.09, 9 rules
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 4.16. MAE = 8.09, 9 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 2.08. MAE = 14.82, 5 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 4.16. MAE = 14.82, 5 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 2.08. MAE = 3.74, 25 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 4.16. MAE = 3.74, 25 rules
#
# **********************
# Best Algorithm.GRIDEX
# **********************
# MAE = 14.82, 5 rules
# Threshold = 2.08
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best   MAE
# **********************
# MAE = 3.74, 25 rules
# Threshold = 2.08
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best N rules
# **********************
# MAE = 33.22, 2 rules
# Threshold = 2.08
# Iterations = 1
# Strategy = Fixed (2)
#
#
# ============CReEPy parameter auto-tuning with CRASH============
#
# Algorithm.CReEPy. Depth: 1. Threshold = 3.75. MAE = 87.71, 2 rules
# Algorithm.CReEPy. Depth: 1. Threshold = 5.83. MAE = 101.96, 2 rules
#
# Algorithm.CReEPy. Depth: 2. Threshold = 3.75. MAE = 64.04, 2 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 5.83. MAE = 48.76, 2 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 7.91. MAE = 76.98, 2 rules
#
# **********************
# Best Algorithm.CReEPy
# **********************
# MAE = 48.76, 2 rules
# Threshold = 5.83
# Depth = 2
#
# **********************
# Best   MAE
# **********************
# MAE = 48.76, 2 rules
# Threshold = 5.83
# Depth = 2
#
# **********************
# Best N rules
# **********************
# MAE = 48.76, 2 rules
# Threshold = 5.83
# Depth = 2
#
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: time, Input features: 1
#
# ============GridREx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 4.02. MAE = 8.96, 2 rules
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 8.04. MAE = 8.96, 2 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 4.02. MAE = 7.16, 4 rules
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 8.04. MAE = 8.20, 3 rules
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 12.05. MAE = 8.96, 2 rules
#
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 4.02. MAE = 7.64, 3 rules
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 8.04. MAE = 7.64, 3 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 4.02. MAE = 6.36, 7 rules
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 8.04. MAE = 6.39, 6 rules
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 12.05. MAE = 10.22, 2 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 4.02. MAE = 6.63, 4 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 8.04. MAE = 6.63, 4 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 4.02. MAE = 4.29, 13 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 8.04. MAE = 4.96, 10 rules
#
# **********************
# Best Algorithm.GRIDREX
# **********************
# MAE = 6.63, 4 rules
# Threshold = 4.02
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best   MAE
# **********************
# MAE = 4.29, 13 rules
# Threshold = 4.02
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best N rules
# **********************
# MAE = 8.96, 2 rules
# Threshold = 4.02
# Iterations = 1
# Strategy = Fixed (2)
#
#
# ============GridEx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 4.02. MAE = 23.80, 2 rules
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 8.04. MAE = 23.80, 2 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 4.02. MAE = 15.34, 4 rules
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 8.04. MAE = 15.34, 4 rules
#
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 4.02. MAE = 22.60, 3 rules
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 8.04. MAE = 22.60, 3 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 4.02. MAE = 9.39, 9 rules
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 8.04. MAE = 9.39, 9 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 4.02. MAE = 14.55, 5 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 8.04. MAE = 14.55, 5 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 4.02. MAE = 6.13, 24 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 8.04. MAE = 7.44, 18 rules
#
# **********************
# Best Algorithm.GRIDEX
# **********************
# MAE = 14.55, 5 rules
# Threshold = 4.02
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best   MAE
# **********************
# MAE = 6.13, 24 rules
# Threshold = 4.02
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best N rules
# **********************
# MAE = 23.80, 2 rules
# Threshold = 4.02
# Iterations = 1
# Strategy = Fixed (2)
#
#
# ============CReEPy parameter auto-tuning with CRASH============
#
# Algorithm.CReEPy. Depth: 1. Threshold = 7.23. MAE = 38.38, 2 rules
# Algorithm.CReEPy. Depth: 1. Threshold = 11.25. MAE = 38.38, 2 rules
#
# Algorithm.CReEPy. Depth: 2. Threshold = 7.23. MAE = 38.38, 2 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 11.25. MAE = 69.44, 2 rules
#
# **********************
# Best Algorithm.CReEPy
# **********************
# MAE = 38.38, 2 rules
# Threshold = 7.23
# Depth = 2
#
# **********************
# Best   MAE
# **********************
# MAE = 38.38, 2 rules
# Threshold = 7.23
# Depth = 2
#
# **********************
# Best N rules
# **********************
# MAE = 38.38, 2 rules
# Threshold = 7.23
# Depth = 2
#
#
# *************************************************************************************
#
# Dataset: contingency, Output variable: cost, Input features: 5
#
# ============GridREx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 0.28. MAE = 20.33, 20 rules
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 0.56. MAE = 20.33, 20 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 0.28. MAE = 17.67, 72 rules
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 0.56. MAE = 17.67, 72 rules
#
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 0.28. MAE = 19.37, 48 rules
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 0.56. MAE = 19.37, 48 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 0.28. MAE = 12.79, 414 rules
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 0.56. MAE = 12.79, 413 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 2)]). Threshold = 0.28. MAE = 26.77, 2 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 2)]). Threshold = 0.56. MAE = 26.77, 2 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 2)]). Threshold = 0.28. MAE = 24.66, 4 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 2)]). Threshold = 0.56. MAE = 24.66, 4 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.75, 2)]). Threshold = 0.28. MAE = 21.77, 10 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.75, 2)]). Threshold = 0.56. MAE = 21.77, 10 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.75, 2)]). Threshold = 0.28. MAE = 20.27, 18 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.75, 2)]). Threshold = 0.56. MAE = 20.27, 18 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 3)]). Threshold = 0.28. MAE = 25.42, 3 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 3)]). Threshold = 0.56. MAE = 25.42, 3 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 3)]). Threshold = 0.28. MAE = 23.41, 9 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 3)]). Threshold = 0.56. MAE = 23.41, 9 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.75, 3)]). Threshold = 0.28. MAE = 23.18, 16 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.75, 3)]). Threshold = 0.56. MAE = 23.18, 16 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.75, 3)]). Threshold = 0.28. MAE = 19.11, 46 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.75, 3)]). Threshold = 0.56. MAE = 19.11, 46 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.28. MAE = 25.10, 5 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.56. MAE = 25.10, 5 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.28. MAE = 20.13, 21 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.56. MAE = 20.13, 21 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 10)]). Threshold = 0.28. MAE = 23.40, 9 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 10)]). Threshold = 0.56. MAE = 23.40, 9 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 10)]). Threshold = 0.28. MAE = 20.17, 51 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 10)]). Threshold = 0.56. MAE = 20.17, 51 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.1, 2), (0.9, 3)]). Threshold = 0.28. MAE = 21.63, 10 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.1, 2), (0.9, 3)]). Threshold = 0.56. MAE = 21.63, 10 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.1, 2), (0.9, 3)]). Threshold = 0.28. MAE = 19.03, 33 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.1, 2), (0.9, 3)]). Threshold = 0.56. MAE = 19.03, 33 rules
#
# **********************
# Best Algorithm.GRIDREX
# **********************
# MAE = 24.66, 4 rules
# Threshold = 0.28
# Iterations = 2
# Strategy = Adaptive ([(0.99, 2)])
#
# **********************
# Best   MAE
# **********************
# MAE = 12.79, 414 rules
# Threshold = 0.28
# Iterations = 2
# Strategy = Fixed (3)
#
# **********************
# Best N rules
# **********************
# MAE = 26.77, 2 rules
# Threshold = 0.28
# Iterations = 1
# Strategy = Adaptive ([(0.99, 2)])
#
#
# ============GridEx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 0.28. MAE = 29.99, 20 rules
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 0.56. MAE = 29.99, 20 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 0.28. MAE = 27.43, 72 rules
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 0.56. MAE = 27.43, 72 rules
#
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 0.28. MAE = 28.62, 48 rules
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 0.56. MAE = 28.62, 48 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 0.28. MAE = 19.40, 414 rules
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 0.56. MAE = 19.40, 414 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 2)]). Threshold = 0.28. MAE = 31.09, 2 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 2)]). Threshold = 0.56. MAE = 31.09, 2 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 2)]). Threshold = 0.28. MAE = 30.50, 4 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 2)]). Threshold = 0.56. MAE = 30.50, 4 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.75, 2)]). Threshold = 0.28. MAE = 29.86, 10 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.75, 2)]). Threshold = 0.56. MAE = 29.86, 10 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.75, 2)]). Threshold = 0.28. MAE = 27.21, 18 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.75, 2)]). Threshold = 0.56. MAE = 27.21, 18 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 3)]). Threshold = 0.28. MAE = 33.55, 3 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 3)]). Threshold = 0.56. MAE = 33.55, 3 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 3)]). Threshold = 0.28. MAE = 27.44, 9 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 3)]). Threshold = 0.56. MAE = 27.44, 9 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.75, 3)]). Threshold = 0.28. MAE = 28.18, 16 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.75, 3)]). Threshold = 0.56. MAE = 28.18, 16 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.75, 3)]). Threshold = 0.28. MAE = 22.70, 46 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.75, 3)]). Threshold = 0.56. MAE = 22.70, 46 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.28. MAE = 28.58, 5 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.56. MAE = 28.58, 5 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.28. MAE = 26.10, 21 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.56. MAE = 26.10, 21 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 10)]). Threshold = 0.28. MAE = 27.69, 9 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 10)]). Threshold = 0.56. MAE = 27.69, 9 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 10)]). Threshold = 0.28. MAE = 23.67, 51 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 10)]). Threshold = 0.56. MAE = 23.67, 51 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.1, 2), (0.9, 3)]). Threshold = 0.28. MAE = 30.13, 10 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.1, 2), (0.9, 3)]). Threshold = 0.56. MAE = 30.13, 10 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.1, 2), (0.9, 3)]). Threshold = 0.28. MAE = 24.98, 33 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.1, 2), (0.9, 3)]). Threshold = 0.56. MAE = 24.98, 33 rules
#
# **********************
# Best Algorithm.GRIDEX
# **********************
# MAE = 28.58, 5 rules
# Threshold = 0.28
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best   MAE
# **********************
# MAE = 19.40, 414 rules
# Threshold = 0.28
# Iterations = 2
# Strategy = Fixed (3)
#
# **********************
# Best N rules
# **********************
# MAE = 31.09, 2 rules
# Threshold = 0.28
# Iterations = 1
# Strategy = Adaptive ([(0.99, 2)])
#
#
# ============CReEPy parameter auto-tuning with CRASH============
#
# Algorithm.CReEPy. Depth: 1. Threshold = 0.50. MAE = 42.65, 2 rules
# Algorithm.CReEPy. Depth: 1. Threshold = 0.78. MAE = 41.86, 2 rules
# Algorithm.CReEPy. Depth: 1. Threshold = 1.06. MAE = 42.81, 2 rules
#
# Algorithm.CReEPy. Depth: 2. Threshold = 0.50. MAE = 42.95, 3 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 0.78. MAE = 42.95, 3 rules
#
# Algorithm.CReEPy. Depth: 3. Threshold = 0.50. MAE = 33.27, 4 rules
# Algorithm.CReEPy. Depth: 3. Threshold = 0.78. MAE = 35.44, 4 rules
#
# **********************
# Best Algorithm.CReEPy
# **********************
# MAE = 33.27, 4 rules
# Threshold = 0.50
# Depth = 3
#
# **********************
# Best   MAE
# **********************
# MAE = 33.27, 4 rules
# Threshold = 0.50
# Depth = 3
#
# **********************
# Best N rules
# **********************
# MAE = 42.81, 2 rules
# Threshold = 1.06
# Depth = 1
#
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: cost, Input features: 5
#
# ============GridREx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 0.02. MAE = 2.47, 20 rules
# Algorithm.GRIDREX. Grid (1). Fixed (2). Threshold = 0.04. MAE = 2.47, 20 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 0.02. MAE = 2.09, 72 rules
# Algorithm.GRIDREX. Grid (2). Fixed (2). Threshold = 0.04. MAE = 2.09, 72 rules
#
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 0.02. MAE = 1.75, 48 rules
# Algorithm.GRIDREX. Grid (1). Fixed (3). Threshold = 0.04. MAE = 1.75, 48 rules
#
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 0.02. MAE = 2.57, 414 rules
# Algorithm.GRIDREX. Grid (2). Fixed (3). Threshold = 0.04. MAE = 2.57, 414 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 2)]). Threshold = 0.02. MAE = 2.66, 2 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 2)]). Threshold = 0.04. MAE = 2.66, 2 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 2)]). Threshold = 0.02. MAE = 2.05, 4 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 2)]). Threshold = 0.04. MAE = 2.05, 4 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 3)]). Threshold = 0.02. MAE = 1.93, 3 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 3)]). Threshold = 0.04. MAE = 1.93, 3 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 3)]). Threshold = 0.02. MAE = 1.75, 9 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 3)]). Threshold = 0.04. MAE = 1.75, 9 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.02. MAE = 1.89, 5 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.04. MAE = 1.89, 5 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.02. MAE = 1.42, 25 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.04. MAE = 1.42, 25 rules
#
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 10)]). Threshold = 0.02. MAE = 1.44, 10 rules
# Algorithm.GRIDREX. Grid (1). Adaptive ([(0.99, 10)]). Threshold = 0.04. MAE = 1.44, 10 rules
#
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 10)]). Threshold = 0.02. MAE = 7.28, 100 rules
# Algorithm.GRIDREX. Grid (2). Adaptive ([(0.99, 10)]). Threshold = 0.04. MAE = 7.28, 100 rules
#
# **********************
# Best Algorithm.GRIDREX
# **********************
# MAE = 1.89, 5 rules
# Threshold = 0.02
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best   MAE
# **********************
# MAE = 1.42, 25 rules
# Threshold = 0.02
# Iterations = 2
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best N rules
# **********************
# MAE = 2.66, 2 rules
# Threshold = 0.02
# Iterations = 1
# Strategy = Adaptive ([(0.99, 2)])
#
#
# ============GridEx parameter auto-tuning with PEDRO============
#
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 0.02. MAE = 15.36, 20 rules
# Algorithm.GRIDEX. Grid (1). Fixed (2). Threshold = 0.04. MAE = 15.36, 20 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 0.02. MAE = 8.90, 72 rules
# Algorithm.GRIDEX. Grid (2). Fixed (2). Threshold = 0.04. MAE = 8.90, 72 rules
#
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 0.02. MAE = 10.41, 48 rules
# Algorithm.GRIDEX. Grid (1). Fixed (3). Threshold = 0.04. MAE = 10.41, 48 rules
#
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 0.02. MAE = 5.71, 414 rules
# Algorithm.GRIDEX. Grid (2). Fixed (3). Threshold = 0.04. MAE = 5.71, 414 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 2)]). Threshold = 0.02. MAE = 18.07, 2 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 2)]). Threshold = 0.04. MAE = 18.07, 2 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 2)]). Threshold = 0.02. MAE = 15.06, 4 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 2)]). Threshold = 0.04. MAE = 15.06, 4 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 3)]). Threshold = 0.02. MAE = 15.27, 3 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 3)]). Threshold = 0.04. MAE = 15.27, 3 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 3)]). Threshold = 0.02. MAE = 14.18, 9 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 3)]). Threshold = 0.04. MAE = 14.18, 9 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.02. MAE = 14.80, 5 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 5)]). Threshold = 0.04. MAE = 14.80, 5 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.02. MAE = 13.98, 25 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 5)]). Threshold = 0.04. MAE = 13.98, 25 rules
#
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 10)]). Threshold = 0.02. MAE = 14.16, 10 rules
# Algorithm.GRIDEX. Grid (1). Adaptive ([(0.99, 10)]). Threshold = 0.04. MAE = 14.16, 10 rules
#
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 10)]). Threshold = 0.02. MAE = 13.95, 100 rules
# Algorithm.GRIDEX. Grid (2). Adaptive ([(0.99, 10)]). Threshold = 0.04. MAE = 13.95, 100 rules
#
# **********************
# Best Algorithm.GRIDEX
# **********************
# MAE = 14.80, 5 rules
# Threshold = 0.02
# Iterations = 1
# Strategy = Adaptive ([(0.99, 5)])
#
# **********************
# Best   MAE
# **********************
# MAE = 5.71, 414 rules
# Threshold = 0.02
# Iterations = 2
# Strategy = Fixed (3)
#
# **********************
# Best N rules
# **********************
# MAE = 18.07, 2 rules
# Threshold = 0.02
# Iterations = 1
# Strategy = Adaptive ([(0.99, 2)])
#
#
# ============CReEPy parameter auto-tuning with CRASH============
#
# Algorithm.CReEPy. Depth: 1. Threshold = 0.03. MAE = 22.19, 2 rules
# Algorithm.CReEPy. Depth: 1. Threshold = 0.05. MAE = 62.56, 2 rules
#
# Algorithm.CReEPy. Depth: 2. Threshold = 0.03. MAE = 62.82, 3 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 0.05. MAE = 59.40, 3 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 0.07. MAE = 20.56, 3 rules
# Algorithm.CReEPy. Depth: 2. Threshold = 0.09. MAE = 21.82, 3 rules
#
# **********************
# Best Algorithm.CReEPy
# **********************
# MAE = 20.56, 3 rules
# Threshold = 0.07
# Depth = 2
#
# **********************
# Best   MAE
# **********************
# MAE = 20.56, 3 rules
# Threshold = 0.07
# Depth = 2
#
# **********************
# Best N rules
# **********************
# MAE = 22.19, 2 rules
# Threshold = 0.03
# Depth = 1
#
#
# *************************************************************************************

# %% [markdown]
# Evaluation of the extractors trained with the best hyper-parameters.
# Only 5 executions per algorithm per dataset, since they generally provide the same results

# %%
def evaluate(extractor, dataset):
    theory = extractor.extract(dataset)
    n = extractor.n_rules
    print(f'{n} rules. ', end='')
    mae = extractor.mae(test)
    print(f'MAE (data) = {mae:.2f}. ', end='')
    fid = extractor.mae(test, model)
    print(f'MAE (BB) = {fid:.2f}')
    return theory, n, mae, fid

# %%
averaged = {
    'GridREx': [],
    'GridEx': [],
    'CReEPy': [],
    'CART': []
}

theories = {
    'GridREx': [],
    'GridEx': [],
    'CReEPy': [],
    'CART': []
}

max_executions = 5

for i, (rem, feat, target, dataset, model) in enumerate(zip(toRemove, features, targets, datasets, models)):
    results = {
        'GridREx': [],
        'GridEx': [],
        'CReEPy': [],
        'CART': []
    }

    print(f"Dataset: {dataset}, Output variable: {target}, Input features: {len(feat)}")

    dataset = pd.read_csv(f"{PATH}datasets/{dataset}.csv").drop(rem, axis = 1)

    train, test = train_test_split(dataset, test_size=0.2, random_state=10)
    model.fit(train.iloc[:, :-1], train.iloc[:, -1])
    E = abs(model.predict(test.iloc[:, :-1]) - test.iloc[:, -1])
    print(f"BB MAE = {E.mean():.2f} +- {E.std():.2f}")

    print("\n============GridREx============\n")
    for j in range(max_executions):
        print(f"Execution #{j + 1}. ", end='')
        gridREx = Extractor.gridrex(model, best_params['GridREx'][i][3], threshold=best_params['GridREx'][i][2])
        theory_from_gridREx, n, mae, fid = evaluate(gridREx, train)
        results['GridREx'].append([n, mae, fid])

    print("\n============GridEx============\n")
    for j in range(max_executions):
        print(f"Execution #{j + 1}. ", end='')
        gridEx = Extractor.gridex(model, best_params['GridEx'][i][3], threshold=best_params['GridEx'][i][2])
        theory_from_gridEx, n, mae, fid = evaluate(gridEx, train)
        results['GridEx'].append([n, mae, fid])

    print("\n============CReEPy============\n")
    for j in range(max_executions):
        print(f"Execution #{j + 1}. ", end='')
        creepy = Extractor.creepy(model, depth=best_params['CReEPy'][i][2],
                                  error_threshold=best_params['CReEPy'][i][3], output=Target.REGRESSION)
        theory_from_creepy, n, mae, fid = evaluate(creepy, train)
        results['CReEPy'].append([n, mae, fid])

    print("\n============CART============\n")
    for j in range(max_executions):
        print(f"Execution #{j + 1}. ", end='')
        cart = Extractor.cart(model, max_leaves=4, simplify=True)
        theory_from_cart, n, mae, fid = evaluate(cart, train)
        results['CART'].append([n, mae, fid])

    print("\n*************************************************************************************\n")

    for extractor, theory in zip(['GridREx', 'GridEx', 'CReEPy', 'CART'],
                                 [theory_from_gridREx, theory_from_gridEx, theory_from_creepy, theory_from_cart]):
        res = np.array(results[extractor]).mean(axis=0)
        std = np.array(results[extractor]).std(axis=0)
        averaged[extractor].append((res, std))
        theories[extractor].append(theory)
# Out:
# Dataset: contingency, Output variable: memo, Input features: 1
# BB MAE = 3.64 +- 4.07
#
# ============GridREx============
#
# Execution #1. 4 rules. MAE (data) = 4.66. MAE (BB) = 2.30
# Execution #2. 4 rules. MAE (data) = 4.66. MAE (BB) = 2.30
# Execution #3. 4 rules. MAE (data) = 4.66. MAE (BB) = 2.30
# Execution #4. 4 rules. MAE (data) = 4.66. MAE (BB) = 2.30
# Execution #5. 4 rules. MAE (data) = 4.66. MAE (BB) = 2.30
#
# ============GridEx============
#
# Execution #1. 4 rules. MAE (data) = 4.68. MAE (BB) = 2.31
# Execution #2. 4 rules. MAE (data) = 4.68. MAE (BB) = 2.31
# Execution #3. 4 rules. MAE (data) = 4.68. MAE (BB) = 2.31
# Execution #4. 4 rules. MAE (data) = 4.68. MAE (BB) = 2.31
# Execution #5. 4 rules. MAE (data) = 4.68. MAE (BB) = 2.31
#
# ============CReEPy============
#
# Execution #1. 2 rules. MAE (data) = 4.65. MAE (BB) = 2.31
# Execution #2. 2 rules. MAE (data) = 4.65. MAE (BB) = 2.31
# Execution #3. 2 rules. MAE (data) = 4.65. MAE (BB) = 2.31
# Execution #4. 2 rules. MAE (data) = 4.65. MAE (BB) = 2.31
# Execution #5. 2 rules. MAE (data) = 4.65. MAE (BB) = 2.31
#
# ============CART============
#
# Execution #1. 4 rules. MAE (data) = 4.52. MAE (BB) = 2.13
# Execution #2. 4 rules. MAE (data) = 4.52. MAE (BB) = 2.13
# Execution #3. 4 rules. MAE (data) = 4.52. MAE (BB) = 2.13
# Execution #4. 4 rules. MAE (data) = 4.52. MAE (BB) = 2.13
# Execution #5. 4 rules. MAE (data) = 4.52. MAE (BB) = 2.13
#
# *************************************************************************************
#
# Dataset: contingency, Output variable: time, Input features: 1
# BB MAE = 0.84 +- 1.00
#
# ============GridREx============
#
# Execution #1. 5 rules. MAE (data) = 0.97. MAE (BB) = 0.67
# Execution #2. 5 rules. MAE (data) = 0.97. MAE (BB) = 0.67
# Execution #3. 5 rules. MAE (data) = 0.97. MAE (BB) = 0.67
# Execution #4. 5 rules. MAE (data) = 0.97. MAE (BB) = 0.67
# Execution #5. 5 rules. MAE (data) = 0.97. MAE (BB) = 0.67
#
# ============GridEx============
#
# Execution #1. 5 rules. MAE (data) = 3.14. MAE (BB) = 3.06
# Execution #2. 5 rules. MAE (data) = 3.14. MAE (BB) = 3.06
# Execution #3. 5 rules. MAE (data) = 3.14. MAE (BB) = 3.06
# Execution #4. 5 rules. MAE (data) = 3.14. MAE (BB) = 3.06
# Execution #5. 5 rules. MAE (data) = 3.14. MAE (BB) = 3.06
#
# ============CReEPy============
#
# Execution #1. 2 rules. MAE (data) = 1.00. MAE (BB) = 0.74
# Execution #2. 2 rules. MAE (data) = 1.00. MAE (BB) = 0.74
# Execution #3. 2 rules. MAE (data) = 1.00. MAE (BB) = 0.74
# Execution #4. 2 rules. MAE (data) = 1.00. MAE (BB) = 0.74
# Execution #5. 2 rules. MAE (data) = 1.00. MAE (BB) = 0.74
#
# ============CART============
#
# Execution #1. 4 rules. MAE (data) = 3.92. MAE (BB) = 3.76
# Execution #2. 4 rules. MAE (data) = 3.92. MAE (BB) = 3.76
# Execution #3. 4 rules. MAE (data) = 3.92. MAE (BB) = 3.76
# Execution #4. 4 rules. MAE (data) = 3.92. MAE (BB) = 3.76
# Execution #5. 4 rules. MAE (data) = 3.92. MAE (BB) = 3.76
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: memo, Input features: 1
# BB MAE = 4.10 +- 3.59
#
# ============GridREx============
#
# Execution #1. 5 rules. MAE (data) = 4.87. MAE (BB) = 3.23
# Execution #2. 5 rules. MAE (data) = 4.87. MAE (BB) = 3.23
# Execution #3. 5 rules. MAE (data) = 4.87. MAE (BB) = 3.23
# Execution #4. 5 rules. MAE (data) = 4.87. MAE (BB) = 3.23
# Execution #5. 5 rules. MAE (data) = 4.87. MAE (BB) = 3.23
#
# ============GridEx============
#
# Execution #1. 5 rules. MAE (data) = 14.97. MAE (BB) = 14.70
# Execution #2. 5 rules. MAE (data) = 14.97. MAE (BB) = 14.70
# Execution #3. 5 rules. MAE (data) = 14.97. MAE (BB) = 14.70
# Execution #4. 5 rules. MAE (data) = 14.97. MAE (BB) = 14.70
# Execution #5. 5 rules. MAE (data) = 14.97. MAE (BB) = 14.70
#
# ============CReEPy============
#
# Execution #1. 2 rules. MAE (data) = 4.92. MAE (BB) = 3.31
# Execution #2. 2 rules. MAE (data) = 4.92. MAE (BB) = 3.31
# Execution #3. 2 rules. MAE (data) = 4.92. MAE (BB) = 3.31
# Execution #4. 2 rules. MAE (data) = 4.92. MAE (BB) = 3.31
# Execution #5. 2 rules. MAE (data) = 4.92. MAE (BB) = 3.31
#
# ============CART============
#
# Execution #1. 4 rules. MAE (data) = 17.37. MAE (BB) = 17.01
# Execution #2. 4 rules. MAE (data) = 17.37. MAE (BB) = 17.01
# Execution #3. 4 rules. MAE (data) = 17.37. MAE (BB) = 17.01
# Execution #4. 4 rules. MAE (data) = 17.37. MAE (BB) = 17.01
# Execution #5. 4 rules. MAE (data) = 17.37. MAE (BB) = 17.01
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: time, Input features: 1
# BB MAE = 8.30 +- 14.85
#
# ============GridREx============
#
# Execution #1. 4 rules. MAE (data) = 11.17. MAE (BB) = 6.61
# Execution #2. 4 rules. MAE (data) = 11.17. MAE (BB) = 6.61
# Execution #3. 4 rules. MAE (data) = 11.17. MAE (BB) = 6.61
# Execution #4. 4 rules. MAE (data) = 11.17. MAE (BB) = 6.61
# Execution #5. 4 rules. MAE (data) = 11.17. MAE (BB) = 6.61
#
# ============GridEx============
#
# Execution #1. 5 rules. MAE (data) = 17.71. MAE (BB) = 15.03
# Execution #2. 5 rules. MAE (data) = 17.71. MAE (BB) = 15.03
# Execution #3. 5 rules. MAE (data) = 17.71. MAE (BB) = 15.03
# Execution #4. 5 rules. MAE (data) = 17.71. MAE (BB) = 15.03
# Execution #5. 5 rules. MAE (data) = 17.71. MAE (BB) = 15.03
#
# ============CReEPy============
#
# Execution #1. 3 rules. MAE (data) = 11.52. MAE (BB) = 7.88
# Execution #2. 3 rules. MAE (data) = 11.52. MAE (BB) = 7.88
# Execution #3. 3 rules. MAE (data) = 11.52. MAE (BB) = 7.88
# Execution #4. 3 rules. MAE (data) = 11.52. MAE (BB) = 7.88
# Execution #5. 3 rules. MAE (data) = 11.52. MAE (BB) = 7.88
#
# ============CART============
#
# Execution #1. 4 rules. MAE (data) = 16.73. MAE (BB) = 12.89
# Execution #2. 4 rules. MAE (data) = 16.73. MAE (BB) = 12.89
# Execution #3. 4 rules. MAE (data) = 16.73. MAE (BB) = 12.89
# Execution #4. 4 rules. MAE (data) = 16.73. MAE (BB) = 12.89
# Execution #5. 4 rules. MAE (data) = 16.73. MAE (BB) = 12.89
#
# *************************************************************************************
#
# Dataset: contingency, Output variable: cost, Input features: 5
# BB MAE = 1.50 +- 4.93
#
# ============GridREx============
#
# Execution #1. 4 rules. MAE (data) = 24.39. MAE (BB) = 24.56
# Execution #2. 4 rules. MAE (data) = 24.39. MAE (BB) = 24.56
# Execution #3. 4 rules. MAE (data) = 24.39. MAE (BB) = 24.56
# Execution #4. 4 rules. MAE (data) = 24.39. MAE (BB) = 24.56
# Execution #5. 4 rules. MAE (data) = 24.39. MAE (BB) = 24.56
#
# ============GridEx============
#
# Execution #1. 5 rules. MAE (data) = 28.52. MAE (BB) = 28.56
# Execution #2. 5 rules. MAE (data) = 28.52. MAE (BB) = 28.56
# Execution #3. 5 rules. MAE (data) = 28.52. MAE (BB) = 28.56
# Execution #4. 5 rules. MAE (data) = 28.52. MAE (BB) = 28.56
# Execution #5. 5 rules. MAE (data) = 28.52. MAE (BB) = 28.56
#
# ============CReEPy============
#
# Execution #1. 4 rules. MAE (data) = 26.68. MAE (BB) = 26.88
# Execution #2. 4 rules. MAE (data) = 26.68. MAE (BB) = 26.88
# Execution #3. 4 rules. MAE (data) = 26.68. MAE (BB) = 26.88
# Execution #4. 4 rules. MAE (data) = 26.68. MAE (BB) = 26.88
# Execution #5. 4 rules. MAE (data) = 26.11. MAE (BB) = 26.28
#
# ============CART============
#
# Execution #1. 4 rules. MAE (data) = 25.07. MAE (BB) = 25.05
# Execution #2. 4 rules. MAE (data) = 25.07. MAE (BB) = 25.05
# Execution #3. 4 rules. MAE (data) = 25.07. MAE (BB) = 25.05
# Execution #4. 4 rules. MAE (data) = 25.07. MAE (BB) = 25.05
# Execution #5. 4 rules. MAE (data) = 25.07. MAE (BB) = 25.05
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: cost, Input features: 5
# BB MAE = 0.41 +- 0.56
#
# ============GridREx============
#
# Execution #1. 5 rules. MAE (data) = 1.91. MAE (BB) = 1.98
# Execution #2. 5 rules. MAE (data) = 1.91. MAE (BB) = 1.98
# Execution #3. 5 rules. MAE (data) = 1.91. MAE (BB) = 1.98
# Execution #4. 5 rules. MAE (data) = 1.91. MAE (BB) = 1.98
# Execution #5. 5 rules. MAE (data) = 1.91. MAE (BB) = 1.98
#
# ============GridEx============
#
# Execution #1. 5 rules. MAE (data) = 14.60. MAE (BB) = 14.60
# Execution #2. 5 rules. MAE (data) = 14.60. MAE (BB) = 14.60
# Execution #3. 5 rules. MAE (data) = 14.60. MAE (BB) = 14.60
# Execution #4. 5 rules. MAE (data) = 14.60. MAE (BB) = 14.60
# Execution #5. 5 rules. MAE (data) = 14.60. MAE (BB) = 14.60
#
# ============CReEPy============
#
# Execution #1. 3 rules. MAE (data) = 1.45. MAE (BB) = 1.52
# Execution #2. 3 rules. MAE (data) = 1.45. MAE (BB) = 1.52
# Execution #3. 3 rules. MAE (data) = 1.45. MAE (BB) = 1.52
# Execution #4. 3 rules. MAE (data) = 1.45. MAE (BB) = 1.52
# Execution #5. 3 rules. MAE (data) = 1.45. MAE (BB) = 1.52
#
# ============CART============
#
# Execution #1. 4 rules. MAE (data) = 14.69. MAE (BB) = 14.69
# Execution #2. 4 rules. MAE (data) = 14.69. MAE (BB) = 14.69
# Execution #3. 4 rules. MAE (data) = 14.69. MAE (BB) = 14.69
# Execution #4. 4 rules. MAE (data) = 14.69. MAE (BB) = 14.69
# Execution #5. 4 rules. MAE (data) = 14.69. MAE (BB) = 14.69
#
# *************************************************************************************

# %% [markdown]
# Aggregated results

# %%
for i, (feat, target, dataset) in enumerate(zip(features, targets, datasets)):
    print(f"Dataset: {dataset}, Output variable: {target}, Input features: {len(feat)}\n")

    for extractor in ['GridREx', 'GridEx', 'CReEPy', 'CART']:
        res, std = averaged[extractor][i]
        print(f'{extractor} average data. {int(res[0])} rules, '
              f'MAE (data) = {res[1]:.2f} +- {std[0]:.2f}, '
              f'MAE (BB) = {res[2]:.2f} +- {std[0]:.2f}.')
    print("\n*************************************************************************************\n")
# Out:
# Dataset: contingency, Output variable: memo, Input features: 1
#
# GridREx average data. 4 rules, MAE (data) = 4.66 +- 0.00, MAE (BB) = 2.30 +- 0.00.
# GridEx average data. 4 rules, MAE (data) = 4.68 +- 0.00, MAE (BB) = 2.31 +- 0.00.
# CReEPy average data. 2 rules, MAE (data) = 4.65 +- 0.00, MAE (BB) = 2.31 +- 0.00.
# CART average data. 4 rules, MAE (data) = 4.52 +- 0.00, MAE (BB) = 2.13 +- 0.00.
#
# *************************************************************************************
#
# Dataset: contingency, Output variable: time, Input features: 1
#
# GridREx average data. 5 rules, MAE (data) = 0.97 +- 0.00, MAE (BB) = 0.67 +- 0.00.
# GridEx average data. 5 rules, MAE (data) = 3.14 +- 0.00, MAE (BB) = 3.06 +- 0.00.
# CReEPy average data. 2 rules, MAE (data) = 1.00 +- 0.00, MAE (BB) = 0.74 +- 0.00.
# CART average data. 4 rules, MAE (data) = 3.92 +- 0.00, MAE (BB) = 3.76 +- 0.00.
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: memo, Input features: 1
#
# GridREx average data. 5 rules, MAE (data) = 4.87 +- 0.00, MAE (BB) = 3.23 +- 0.00.
# GridEx average data. 5 rules, MAE (data) = 14.97 +- 0.00, MAE (BB) = 14.70 +- 0.00.
# CReEPy average data. 2 rules, MAE (data) = 4.92 +- 0.00, MAE (BB) = 3.31 +- 0.00.
# CART average data. 4 rules, MAE (data) = 17.37 +- 0.00, MAE (BB) = 17.01 +- 0.00.
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: time, Input features: 1
#
# GridREx average data. 4 rules, MAE (data) = 11.17 +- 0.00, MAE (BB) = 6.61 +- 0.00.
# GridEx average data. 5 rules, MAE (data) = 17.71 +- 0.00, MAE (BB) = 15.03 +- 0.00.
# CReEPy average data. 3 rules, MAE (data) = 11.52 +- 0.00, MAE (BB) = 7.88 +- 0.00.
# CART average data. 4 rules, MAE (data) = 16.73 +- 0.00, MAE (BB) = 12.89 +- 0.00.
#
# *************************************************************************************
#
# Dataset: contingency, Output variable: cost, Input features: 5
#
# GridREx average data. 4 rules, MAE (data) = 24.39 +- 0.00, MAE (BB) = 24.56 +- 0.00.
# GridEx average data. 5 rules, MAE (data) = 28.52 +- 0.00, MAE (BB) = 28.56 +- 0.00.
# CReEPy average data. 4 rules, MAE (data) = 26.56 +- 0.00, MAE (BB) = 26.76 +- 0.00.
# CART average data. 4 rules, MAE (data) = 25.07 +- 0.00, MAE (BB) = 25.05 +- 0.00.
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: cost, Input features: 5
#
# GridREx average data. 5 rules, MAE (data) = 1.91 +- 0.00, MAE (BB) = 1.98 +- 0.00.
# GridEx average data. 5 rules, MAE (data) = 14.60 +- 0.00, MAE (BB) = 14.60 +- 0.00.
# CReEPy average data. 3 rules, MAE (data) = 1.45 +- 0.00, MAE (BB) = 1.52 +- 0.00.
# CART average data. 4 rules, MAE (data) = 14.69 +- 0.00, MAE (BB) = 14.69 +- 0.00.
#
# *************************************************************************************

# %% [markdown]
# Example of output theories for each dataset for each extractor

# %%
for i, (feat, target, dataset) in enumerate(zip(features, targets, datasets)):
    print(f"Dataset: {dataset}, Output variable: {target}, Input features: {len(feat)}")

    for extractor in ['GridREx', 'GridEx', 'CReEPy', 'CART']:
        print(f"\n============{extractor}============\n")
        print(f'{extractor} extracted rules (last execution):\n' + pretty_theory(theories[extractor][i]))
    print("\n*************************************************************************************\n")
# Out:
# Dataset: contingency, Output variable: memo, Input features: 1
#
# ============GridREx============
#
# GridREx extracted rules (last execution):
# memo(NTraces, Memo) :-
#     NTraces in [33.99, 100.00], Memo is 88.22 + 0.03 * NTraces.
# memo(NTraces, Memo) :-
#     NTraces in [0.99, 11.99], Memo is 87.12 + -0.04 * NTraces.
# memo(NTraces, Memo) :-
#     NTraces in [11.99, 22.99], Memo is 80.77 + 0.40 * NTraces.
# memo(NTraces, Memo) :-
#     NTraces in [22.99, 33.99], Memo is 82.42 + 0.20 * NTraces.
#
# ============GridEx============
#
# GridEx extracted rules (last execution):
# memo(NTraces, 87.21) :-
#     NTraces in [0.99, 25.74].
# memo(NTraces, 90.13) :-
#     NTraces in [25.74, 50.5].
# memo(NTraces, 89.07) :-
#     NTraces in [50.5, 75.25].
# memo(NTraces, 91.41) :-
#     NTraces in [75.25, 100.00].
#
# ============CReEPy============
#
# CReEPy extracted rules (last execution):
# memo(NTraces, Memo) :-
#     NTraces in [30.99, 100.00], Memo is 87.58 + 0.04 * NTraces.
# memo(NTraces, Memo) :-
#     NTraces in [0.99, 100.00], Memo is 85.98 + 0.10 * NTraces.
#
# ============CART============
#
# CART extracted rules (last execution):
# memo(NTraces, 87.20) :-
#     NTraces =< 29.5.
# memo(NTraces, 96.97) :-
#     NTraces > 99.5.
# memo(NTraces, 94.73) :-
#     NTraces =< 30.5.
# memo(NTraces, 90.100316).
#
# *************************************************************************************
#
# Dataset: contingency, Output variable: time, Input features: 1
#
# ============GridREx============
#
# GridREx extracted rules (last execution):
# time(NTraces, Time) :-
#     NTraces in [0.99, 20.79], Time is 5.05 + 0.59 * NTraces.
# time(NTraces, Time) :-
#     NTraces in [20.79, 40.6], Time is 2.27 + 0.71 * NTraces.
# time(NTraces, Time) :-
#     NTraces in [40.6, 60.4], Time is 12.13 + 0.47 * NTraces.
# time(NTraces, Time) :-
#     NTraces in [60.4, 80.20], Time is 9.31 + 0.54 * NTraces.
# time(NTraces, Time) :-
#     NTraces in [80.20, 100.00], Time is 9.81 + 0.54 * NTraces.
#
# ============GridEx============
#
# GridEx extracted rules (last execution):
# time(NTraces, 11.30) :-
#     NTraces in [0.99, 20.79].
# time(NTraces, 24.30) :-
#     NTraces in [20.79, 40.6].
# time(NTraces, 36.06) :-
#     NTraces in [40.6, 60.4].
# time(NTraces, 47.97) :-
#     NTraces in [60.4, 80.20].
# time(NTraces, 59.13) :-
#     NTraces in [80.20, 100.00].
#
# ============CReEPy============
#
# CReEPy extracted rules (last execution):
# time(NTraces, Time) :-
#     NTraces in [31.99, 100.00], Time is 7.80 + 0.56 * NTraces.
# time(NTraces, Time) :-
#     NTraces in [0.99, 100.00], Time is 5.05 + 0.59 * NTraces.
#
# ============CART============
#
# CART extracted rules (last execution):
# time(NTraces, 13.08) :-
#     NTraces =< 50.5, NTraces =< 26.5.
# time(NTraces, 29.45) :-
#     NTraces =< 50.5, NTraces > 26.5.
# time(NTraces, 42.02) :-
#     NTraces =< 71.5.
# time(NTraces, 56.667674).
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: memo, Input features: 1
#
# ============GridREx============
#
# GridREx extracted rules (last execution):
# memo(NScenarios, Memo) :-
#     NScenarios in [0.99, 20.79], Memo is 66.20 + 4.02 * NScenarios.
# memo(NScenarios, Memo) :-
#     NScenarios in [20.79, 40.6], Memo is 88.71 + 2.59 * NScenarios.
# memo(NScenarios, Memo) :-
#     NScenarios in [40.6, 60.4], Memo is 83.04 + 2.68 * NScenarios.
# memo(NScenarios, Memo) :-
#     NScenarios in [60.4, 80.20], Memo is 77.25 + 2.73 * NScenarios.
# memo(NScenarios, Memo) :-
#     NScenarios in [80.20, 100.00], Memo is 107.64 + 2.30 * NScenarios.
#
# ============GridEx============
#
# GridEx extracted rules (last execution):
# memo(NScenarios, 108.36) :-
#     NScenarios in [0.99, 20.79].
# memo(NScenarios, 168.63) :-
#     NScenarios in [20.79, 40.6].
# memo(NScenarios, 219.42) :-
#     NScenarios in [40.6, 60.4].
# memo(NScenarios, 270.62) :-
#     NScenarios in [60.4, 80.20].
# memo(NScenarios, 317.22) :-
#     NScenarios in [80.20, 100.00].
#
# ============CReEPy============
#
# CReEPy extracted rules (last execution):
# memo(NScenarios, Memo) :-
#     NScenarios in [9.99, 100.00], Memo is 91.14 + 2.51 * NScenarios.
# memo(NScenarios, Memo) :-
#     NScenarios in [0.99, 100.00], Memo is 62.89 + 4.54 * NScenarios.
#
# ============CART============
#
# CART extracted rules (last execution):
# memo(NScenarios, 104.86) :-
#     NScenarios =< 49.5, NScenarios =< 19.5.
# memo(NScenarios, 177.01) :-
#     NScenarios =< 49.5, NScenarios > 19.5.
# memo(NScenarios, 246.28) :-
#     NScenarios =< 73.5.
# memo(NScenarios, 309.25037).
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: time, Input features: 1
#
# ============GridREx============
#
# GridREx extracted rules (last execution):
# time(NScenarios, Time) :-
#     NScenarios in [40.6, 60.4], Time is -113.08 + 4.75 * NScenarios.
# time(NScenarios, Time) :-
#     NScenarios in [60.4, 80.20], Time is 178.93 + -0.18 * NScenarios.
# time(NScenarios, Time) :-
#     NScenarios in [80.20, 100.00], Time is -41.11 + 2.52 * NScenarios.
# time(NScenarios, Time) :-
#     NScenarios in [0.99, 40.6], Time is -5.26 + 2.06 * NScenarios.
#
# ============GridEx============
#
# GridEx extracted rules (last execution):
# time(NScenarios, 16.43) :-
#     NScenarios in [0.99, 20.79].
# time(NScenarios, 58.16) :-
#     NScenarios in [20.79, 40.6].
# time(NScenarios, 128.55) :-
#     NScenarios in [40.6, 60.4].
# time(NScenarios, 165.71) :-
#     NScenarios in [60.4, 80.20].
# time(NScenarios, 188.46) :-
#     NScenarios in [80.20, 100.00].
#
# ============CReEPy============
#
# CReEPy extracted rules (last execution):
# time(NScenarios, Time) :-
#     NScenarios in [46.99, 100.00], Time is 77.39 + 1.23 * NScenarios.
# time(NScenarios, Time) :-
#     NScenarios in [38.99, 100.00], Time is -12.16 + 2.35 * NScenarios.
# time(NScenarios, Time) :-
#     NScenarios in [0.99, 100.00], Time is -4.41 + 2.00 * NScenarios.
#
# ============CART============
#
# CART extracted rules (last execution):
# time(NScenarios, 21.11) :-
#     NScenarios =< 46.5, NScenarios =< 25.5.
# time(NScenarios, 71.40) :-
#     NScenarios =< 46.5, NScenarios > 25.5.
# time(NScenarios, 158.40) :-
#     NScenarios =< 86.5.
# time(NScenarios, 197.106106).
#
# *************************************************************************************
#
# Dataset: contingency, Output variable: cost, Input features: 5
#
# ============GridREx============
#
# GridREx extracted rules (last execution):
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, Cost) :-
#     Load_std in [157.50, 163.43], Cost is 1049.74 + 45.00 * Load_mean + -21.52 * Load_std + -17.90 * PV_mean + -7.14 * PV_std + -0.01 * NTraces.
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, Cost) :-
#     Load_std in [163.43, 169.35], Cost is -371.95 + -7.13 * Load_mean + 4.00 * Load_std + 4.11 * PV_mean + 1.43 * PV_std + -0.30 * NTraces.
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, Cost) :-
#     Load_std in [169.35, 175.28], Cost is -1118.47 + 4.30 * Load_mean + -2.31 * Load_std + -1.65 * PV_mean + 8.96 * PV_std + -0.30 * NTraces.
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, Cost) :-
#     Load_std in [175.28, 181.20], Cost is -449.20 + 5.29 * Load_mean + -11.41 * Load_std + 25.29 * PV_mean + -32.42 * PV_std + -0.25 * NTraces.
#
# ============GridEx============
#
# GridEx extracted rules (last execution):
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, 337.41) :-
#     Load_std in [157.50, 162.24].
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, 340.14) :-
#     Load_std in [162.24, 166.98].
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, 372.75) :-
#     Load_std in [166.98, 171.72].
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, 410.52) :-
#     Load_std in [171.72, 176.46].
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, 514.16) :-
#     Load_std in [176.46, 181.20].
#
# ============CReEPy============
#
# CReEPy extracted rules (last execution):
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, Cost) :-
#     PV_mean in [251.43, 277.45], PV_std in [260.01, 283.33], Load_mean in [299.34, 328.87], Load_std in [157.50, 170.76], NTraces in [0.99, 100.00], Cost is -432.08 + -5.56 * Load_mean + 3.38 * Load_std + 3.44 * PV_mean + 1.56 * PV_std + -0.22 * NTraces.
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, Cost) :-
#     PV_mean in [251.43, 281.42], PV_std in [260.01, 290.06], Load_mean in [299.34, 332.16], Load_std in [157.50, 173.09], NTraces in [0.99, 100.00], Cost is -2684.26 + 17.30 * Load_mean + -14.18 * Load_std + -1.06 * PV_mean + 15.73 * PV_std + -0.28 * NTraces.
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, Cost) :-
#     PV_mean in [251.43, 281.42], PV_std in [260.01, 290.06], Load_mean in [299.34, 332.16], Load_std in [157.50, 176.42], NTraces in [0.99, 100.00], Cost is -2151.79 + 30.15 * Load_mean + -7.83 * Load_std + 14.62 * PV_mean + -47.51 * PV_std + -0.26 * NTraces.
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, Cost) :-
#     PV_mean in [251.43, 293.42], PV_std in [260.01, 301.55], Load_mean in [299.34, 346.84], Load_std in [157.50, 181.20], NTraces in [0.99, 100.00], Cost is -932.00 + -3027.46 * Load_mean + 965.39 * Load_std + 2450.70 * PV_mean + -1386.79 * PV_std + -0.49 * NTraces.
#
# ============CART============
#
# CART extracted rules (last execution):
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, 340.99) :-
#     Load_std =< 168.30.
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, 548.58) :-
#     Load_mean > 343.17.
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, 400.78) :-
#     NTraces =< 89.5.
# cost(Load_mean, Load_std, PV_mean, PV_std, NTraces, 347.659686).
#
# *************************************************************************************
#
# Dataset: anticipate, Output variable: cost, Input features: 5
#
# ============GridREx============
#
# GridREx extracted rules (last execution):
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, Cost) :-
#     NScenarios in [0.99, 20.79], Cost is -15.71 + -3.32 * Load_mean + -0.14 * Load_std + 3.53 * PV_mean + 1.20 * PV_std + -0.66 * NScenarios.
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, Cost) :-
#     NScenarios in [20.79, 40.6], Cost is 14.15 + -3.35 * Load_mean + -0.09 * Load_std + 3.51 * PV_mean + 1.18 * PV_std + -1.81 * NScenarios.
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, Cost) :-
#     NScenarios in [40.6, 60.4], Cost is -20.35 + -3.32 * Load_mean + -0.15 * Load_std + 3.53 * PV_mean + 1.21 * PV_std + -0.96 * NScenarios.
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, Cost) :-
#     NScenarios in [60.4, 80.20], Cost is -19.63 + -3.30 * Load_mean + -0.17 * Load_std + 3.52 * PV_mean + 1.22 * PV_std + -0.96 * NScenarios.
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, Cost) :-
#     NScenarios in [80.20, 100.00], Cost is -22.04 + -3.30 * Load_mean + -0.17 * Load_std + 3.52 * PV_mean + 1.23 * PV_std + -0.94 * NScenarios.
#
# ============GridEx============
#
# GridEx extracted rules (last execution):
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, 373.06) :-
#     NScenarios in [0.99, 20.79].
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, 354.49) :-
#     NScenarios in [20.79, 40.6].
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, 329.08) :-
#     NScenarios in [40.6, 60.4].
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, 309.83) :-
#     NScenarios in [60.4, 80.20].
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, 290.67) :-
#     NScenarios in [80.20, 100.00].
#
# ============CReEPy============
#
# CReEPy extracted rules (last execution):
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, Cost) :-
#     PV_mean in [261.18, 293.42], PV_std in [268.41, 301.55], Load_mean in [308.72, 346.84], Load_std in [159.83, 181.20], NScenarios in [30.99, 100.00], Cost is -33.39 + -3.30 * Load_mean + -0.13 * Load_std + 3.52 * PV_mean + 1.24 * PV_std + -0.95 * NScenarios.
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, Cost) :-
#     PV_mean in [251.43, 293.42], PV_std in [260.01, 301.55], Load_mean in [299.34, 346.84], Load_std in [157.50, 181.20], NScenarios in [30.99, 100.00], Cost is -316285715.97 + -74260062.27 * Load_mean + 19497049.77 * Load_std + 74578003.14 * PV_mean + -53371771.06 * PV_std + -0.95 * NScenarios.
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, Cost) :-
#     PV_mean in [251.43, 293.42], PV_std in [260.01, 301.55], Load_mean in [299.34, 346.84], Load_std in [157.50, 181.20], NScenarios in [0.99, 100.00], Cost is -17.03 + -3.31 * Load_mean + -0.16 * Load_std + 3.52 * PV_mean + 1.21 * PV_std + -0.56 * NScenarios.
#
# ============CART============
#
# CART extracted rules (last execution):
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, 321.44) :-
#     NScenarios > 44.5, NScenarios =< 73.5.
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, 294.10) :-
#     NScenarios > 44.5, NScenarios > 73.5.
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, 370.49) :-
#     NScenarios =< 30.5.
# cost(Load_mean, Load_std, PV_mean, PV_std, NScenarios, 342.173846).
#
# *************************************************************************************
