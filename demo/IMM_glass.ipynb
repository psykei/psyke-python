# %%
import numpy as np
from psyke import Extractor
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
import plotly.express as px


X_path="datasets\X_Glass.npy"
Y_path="datasets\Y_Glass.npy"

X=np.load(X_path)
Y=np.load(Y_path)

# %%
class_expected=np.unique(Y)
print("Number of expected class are:", class_expected)
# Out:
# Number of expected class are: [0 1 2 3 4 5]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
import matplotlib.pyplot as plt
df = pd.DataFrame(pd.concat([pd.DataFrame(X,columns=[0,1,2,3,4,5,6,7,8]),pd.DataFrame(Y,columns=[9])],axis=1))

fig = px.scatter_matrix(df,
    dimensions=[0,1,2,3,4,5,6,7,8])
fig.show()

# %% [markdown]
# Looking at the combination of features 7 and 2 there are 4 classes.

# %%
exact_cluster_to_search=len(np.unique(Y_train))
n_cluster=4

# %%
#initialize with n clusters
imm = Extractor.imm(exact_cluster_to_search)
imm.fit(X_train)
imm.drawTree()

Y_pred_1=imm.predict_on_more_data(X_test)

print('rand_score is: ',metrics.rand_score(Y_test,Y_pred_1),' , ARI score is : ',metrics.adjusted_rand_score(Y_test,Y_pred_1),' , AMI score is: ',metrics.adjusted_mutual_info_score(Y_test,Y_pred_1),' , silhoutte score is: ',metrics.silhouette_score(X_test,Y_pred_1))
# Out:
# rand_score is:  0.6788482834994463  , ARI score is :  0.2707967854577047  , AMI score is:  0.35727278545899266  , silhoutte score is:  0.38564113427831276

# %%
#initialize with n clusters
imm = Extractor.imm(n_cluster)
imm.fit(X_train)
imm.drawTree()

Y_pred_2=imm.predict_on_more_data(X_test)

print('rand_score is: ',metrics.rand_score(Y_test,Y_pred_2),' , ARI score is : ',metrics.adjusted_rand_score(Y_test,Y_pred_2),' , AMI score is: ',metrics.adjusted_mutual_info_score(Y_test,Y_pred_2),' , silhoutte score is: ',metrics.silhouette_score(X_test,Y_pred_2))
# Out:
# rand_score is:  0.6998892580287929  , ARI score is :  0.31957825546574575  , AMI score is:  0.43027257459739915  , silhoutte score is:  0.3142699852241563

# %%
df_test=pd.DataFrame(pd.concat([pd.DataFrame(X_test,columns=[0,1,2,3,4,5,6,7,8]),pd.DataFrame(Y_test,columns=[9])],axis=1))

# %%
fig = px.scatter_matrix(df_test,
    dimensions=[0,1,2,3,4,5,6,7,8],
    color=9)
fig.show()

# %%
fig = px.scatter_matrix(df_test,
    dimensions=[2,7],
    color=9)
fig.show()

# %%
df_pred=pd.DataFrame(pd.concat([pd.DataFrame(X_test,columns=[0,1,2,3,4,5,6,7,8]),pd.DataFrame(Y_pred_1,columns=[9])],axis=1))
fig = px.scatter_matrix(df_pred,
    dimensions=[2,7],
    color=9)
fig.show()

# %%
df_pred=pd.DataFrame(pd.concat([pd.DataFrame(X_test,columns=[0,1,2,3,4,5,6,7,8]),pd.DataFrame(Y_pred_2,columns=[9])],axis=1))
fig = px.scatter_matrix(df_pred,
    dimensions=[2,7],
    color=9)
fig.show()
